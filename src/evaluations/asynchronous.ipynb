# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Results for each epochs

# %% [markdown]
# ## epoch 1

# %%
loss_1 = 0.0128
binary_accuracy_1 = 0.9978
true_positives_1 = 1144
true_negatives_1 = 553351
false_positives_1 = 223
false_negatives_1 = 1001
precision_1 = 0.8369 
recall_1 = 0.5333

# %% [markdown]
# ## Epoch 2

# %%
loss_2 = (0.0135 + 0.0128) / 2
binary_accuracy_2 = 0.9978
true_positives_2 = 537+618
true_negatives_2 = 276222+277105
false_positives_2 = 125+122
false_negatives_2 = 499+491
precision_2 = (0.8112+0.8351)/2
recall_2 = (0.5183+0.5573)/2

# %% [markdown]
# ## Epoch 3

# %%
loss_3 = (0.0130+0.0146+0.0123) / 3
binary_accuracy_3 = (0.9977+0.9974+0.9982) / 3
true_positives_3 = 373+429+363
true_negatives_3 = 184671+184643+183995
false_positives_3 = 84+92+89
false_negatives_3 = 339+389+252
precision_3 = (0.8162+0.8234+0.8031)/3
recall_3 = (0.5239+0.5244+0.5902)/3

# %% [markdown]
# ## Epoch 4

# %%
loss_4 = (0.0138+0.0135+0.0142+0.0125) / 4
binary_accuracy_4 = (0.9977+0.9980+0.9974+0.9979) / 4
true_positives_4 = 297+239+303+333
true_negatives_4 = 138039+138103+138110+139054
false_positives_4 = 72+58+76+62
false_negatives_4 = 246+216+278+233
precision_4 = (0.8049+0.8047+0.7995+0.8430) / 4
recall_4 = (0.5470+0.5253+0.5215+0.5883) / 4

# %% [markdown]
# ## Epoch 5

# %%
loss_5 = (0.0128+0.0140+0.0132+0.0126+0.0158) / 5
binary_accuracy_5 = (0.9980+0.9974+0.9981+0.9983+0.9969) / 5
true_positives_5 = 197+300+221+136+325
true_negatives_5 = 110486+109915+110760+110754+111373
false_positives_5 = 53+54+40+61+78
false_negatives_5 = 168+232+174+123+269
precision_5 = (0.7880+0.8475+0.8467+0.6904+0.8065) / 5
recall_5 = (0.5397+0.5639+0.5595+0.5251+0.5471) / 5

# %% [markdown]
# ## Epoch 6

# %%
loss_6 = (0.0134+0.0149+0.0142+0.0124+0.0132+0.0151) / 6
binary_accuracy_6 = (0.9981+0.9973+0.9975+0.9982+0.9979+0.9974) / 6
true_positives_6 = 168+245+189+202+201+192
true_negatives_6 = 91483+91892+91969+92500+92688+92738
false_positives_6 = 62+47+37+39+61+58
false_negatives_6 = 114+199+191+131+131+182
precision_6 = (0.7304+0.8390+0.8363+0.8382+0.7672+0.7680) / 6
recall_6 = (0.5957+0.5518+0.4974+0.6066+0.6054+0.5134) / 6

# %% [markdown]
# # Epoch 7

# %%
loss_7 = (0.0151+0.0123+0.0140+0.0154+0.0127+0.0145+0.0142) / 7
binary_accuracy_7 = (0.9975+0.9983+0.9976+0.9974+0.9981+0.9974+0.9975) / 7
precision_7 = (0.7269+0.7703+0.7800+0.7826+0.7598+0.7901+0.8482) / 7
recall_7 = (0.5500+0.5327+0.5200+0.5723+0.5985+0.5517+0.5767) / 7

# %% [markdown]
# # Epoch 8

# %%
loss_8 = (0.0148+0.0144+0.0152+0.0143+0.0139+0.0121+0.0142+0.0135) / 8
binary_accuracy_8 = (0.9978+0.9975+0.9974+0.9978+0.9977+0.9981+0.9974+0.9981) / 8
precision_8 = (0.7063+0.7917+0.7925+0.7708+0.8452+0.8057+0.7500+0.8160) / 8
recall_8 = (0.5136+0.5278+0.5526+0.5804+0.6196+0.5875+0.5090+0.5660) / 8

# %% [markdown]
# # Epoch 9

# %%
loss_9 = (0.0149+0.0164+0.0142+0.0120+0.0137+0.0131+0.0149+0.0152+0.0134) / 9
binary_accuracy_9 = (0.9975+0.9970+0.9978+0.9982+0.9980+0.9978+0.9974+0.9973+0.9984) / 9
precision_9 = (0.7579+0.8280+0.7869+0.7463+0.7283+0.7935+0.8398+0.7845+0.7823) / 9
recall_9 = (0.5692+0.5033+0.5926+0.5682+0.6411+0.5395+0.5371+0.5279+0.6461) / 9

# %% [markdown]
# # Epoch 10

# %%
loss_10 = (0.0139+0.0151+0.0139+0.0160+0.0139+0.0136+0.0117+0.0150+0.0125+0.0168) / 10
binary_accuracy_10 = (0.9976+0.9972+0.9980+0.9969+0.9981+0.9980+0.9984+0.9977+0.9986+0.9969) / 10
precision_10 = (0.8013+0.8472+0.6797+0.7386+0.8682+0.7887+0.8033+0.7554+0.6420+0.8221) / 10
recall_10 = (0.5402+0.5942+0.5613+0.5118+0.5572+0.5773+0.6012+0.5198+0.5000+0.6118) / 10

# %% [markdown]
# ---

# %%
loss = [loss_1, loss_2, loss_3, loss_4, loss_5, loss_6, loss_7, loss_8, loss_9, loss_10]
binary_accuracy = [binary_accuracy_1, binary_accuracy_2, binary_accuracy_3, binary_accuracy_4, binary_accuracy_5, binary_accuracy_6, binary_accuracy_7, binary_accuracy_8, binary_accuracy_9, binary_accuracy_10]
precision = [precision_1, precision_2, precision_3, precision_4, precision_5, precision_6, precision_7, precision_8, precision_9, precision_10]
recall = [recall_1, recall_2, recall_3, recall_4, recall_5, recall_6, recall_7, recall_8, recall_9, recall_10]

# %%
# Plot ROC curve using Matplotlib
plt.plot(range(1,11), loss, label='Loss')
plt.xlabel('num_workers')
plt.ylabel('Loss')
plt.title('Loss trend')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot ROC curve using Matplotlib
plt.plot(range(1,11), binary_accuracy, label='Accuracy')
plt.xlabel('num_workers')
plt.ylabel('Accuracy')
plt.title('Accuracy trend')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot ROC curve using Matplotlib
plt.plot(range(1,11), precision, label='Precision')
plt.xlabel('num_workers')
plt.ylabel('Precision')
plt.title('Precision trend')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot ROC curve using Matplotlib
plt.plot(range(1,11), recall, label='Recall')
plt.xlabel('num_workers')
plt.ylabel('Recall')
plt.title('Recall trend')
plt.legend(loc="lower right")
plt.show()
