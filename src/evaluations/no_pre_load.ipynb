# %%
import sys
sys.path.append('../')

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import pandas as pd
import numpy as np

# %%
path = '../'

# %%
df = pd.read_csv(f'{path}training_runs/no_preload_evaluation.csv')
df['f1_score'] = 2 * (df['precision'] * df['recall']) / (df['precision'] + df['recall'])
df
# Out:
#                              model      loss  binary_accuracy      TP
# 0               feedzai_production  0.021477         0.995316  1142.0  \
# 1         feedzai_extra_production  0.015406         0.994578  1416.0
# 2        feedzai_concat_production  0.016204         0.996111   327.0
# 3  feedzai_extra_concat_production  0.017675         0.996133   117.0
# 4                double_production  0.012178         0.996986   869.0
# 5          double_extra_production  0.021569         0.995730   209.0
# 6         double_concat_production  0.015500         0.996182   132.0
# 7   double_extra_concat_production  0.018039         0.995955   150.0
#
#          TN      FP      FN  precision    recall       auc  f1_score
# 0  551974.0  1600.0  1003.0   0.416484  0.532401  0.929049  0.467362
# 1  551290.0  2284.0   729.0   0.382703  0.660140  0.938997  0.484517
# 2  553231.0   343.0  1818.0   0.488060  0.152448  0.872927  0.232327
# ...
