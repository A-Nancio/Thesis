# %%
import sys
sys.path.append('../')

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from keras.layers import Dense, Dropout

import tensorflow as tf
import numpy as np
from tqdm import tqdm
from keras.layers import Dense, Dropout, GRU

import pandas as pd
import tensorflow as tf
import numpy as np

tf.random.set_seed(42)
from machine_learning.models import FeedzaiTrain, FeedzaiProduction, FeedzaiExtraTrain, FeedzaiExtraProduction, FeedzaiConcatTrain, FeedzaiConcatProduction, FeedzaiExtraConcatTrain, FeedzaiExtraConcatProduction, DoubleTrain, DoubleProduction, DoubleExtraTrain, DoubleExtraProduction, DoubleConcatTrain, DoubleConcatProduction, DoubleExtraConcatTrain, DoubleExtraConcatProduction
pd.options.display.max_rows = 250

# %%
path = '../'

# %%
model = DoubleExtraConcatProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df

# %% [markdown]
# # Final Results

# %%
# FINAL RESULTS
results = {
    DoubleProduction: 8,
    DoubleExtraProduction: 14,
    DoubleConcatProduction: 18,
    DoubleExtraConcatProduction: 19,
    FeedzaiProduction: 15,
    FeedzaiExtraProduction: 19,
    FeedzaiConcatProduction: 11,
    FeedzaiExtraConcatProduction: 17
}

# %% [markdown]
# # Double

# %% [markdown]
# ### Double

# %%
model = DoubleProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] = 2 * (train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP      FN
# epoch
# 0       2.0  0.024062         0.995450  563.2  554048.2  274.6  2058.6  \
# 1       2.0  0.021941         0.995723  614.8  554061.8  261.0  2007.0
# 2       2.0  0.022452         0.995526  363.4  554168.2  154.6  2258.4
# 3       2.0  0.022024         0.995572  383.8  554173.2  149.6  2238.0
# 4       2.0  0.021496         0.995560  411.0  554139.4  183.4  2210.8
# 5       2.0  0.020950         0.995581  423.2  554142.4  180.4  2198.6
# 6       2.0  0.020422         0.995661  542.6  554082.6  240.2  2079.2
# 7       2.0  0.019879         0.995740  679.2  553998.6  324.2  1942.6
# 8       2.0  0.019513         0.995815  724.4  554010.6  312.2  1897.4
# 9       2.0  0.019386         0.995805  724.2  554012.6  310.2  1897.6
# 10      2.0  0.019230         0.995869  740.0  554025.8  297.0  1881.8
# 11      2.0  0.019740         0.995738  599.2  554076.6  246.2  2022.6
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.021971         0.995462   67.0  127040.2  141.0  438.4  \
# 1       2.0  0.020445         0.995490  130.0  126980.8  200.4  375.4
# 2       2.0  0.021292         0.995488   76.4  127034.2  147.0  429.0
# 3       2.0  0.020978         0.995648   68.0  127063.0  118.2  437.4
# 4       2.0  0.021346         0.995385   87.2  127010.2  171.0  418.2
# 5       2.0  0.020105         0.995576   93.8  127028.0  153.2  411.6
# 6       2.0  0.019851         0.995807   69.8  127081.4   99.8  435.6
# 7       2.0  0.020267         0.995912  130.8  127033.8  147.4  374.6
# 8       2.0  0.019796         0.995921  148.8  127017.0  164.2  356.6
# 9       2.0  0.019480         0.995636  151.0  126978.4  202.8  354.4
# 10      2.0  0.019951         0.995498  145.4  126966.4  214.8  360.0
# 11      2.0  0.020485         0.995349  117.6  126975.2  206.0  387.8
# ...

# %% [markdown]
# ### Double Extra

# %%
model = DoubleExtraProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] = 2 * (train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP      FN
# epoch
# 0       2.0  0.033415         0.990043  563.2  553349.6  973.2  2058.6  \
# 1       2.0  0.022304         0.995646  559.8  554068.4  254.4  2062.0
# 2       2.0  0.022092         0.995631  547.4  554066.2  256.6  2074.4
# 3       2.0  0.021438         0.995658  564.2  554073.6  249.2  2057.6
# 4       2.0  0.021054         0.995683  564.6  554096.0  226.8  2057.2
# 5       2.0  0.020568         0.995672  570.6  554075.6  247.2  2051.2
# 6       2.0  0.020329         0.995721  613.6  554066.0  256.8  2008.2
# 7       2.0  0.020181         0.995726  603.0  554063.2  259.6  2018.8
# 8       2.0  0.020077         0.995761  636.4  554056.0  266.8  1985.4
# 9       2.0  0.020032         0.995738  622.2  554051.6  271.2  1999.6
# 10      2.0  0.019857         0.995797  664.2  554058.0  264.8  1957.6
# 11      2.0  0.019672         0.995820  699.6  554031.6  291.2  1922.2
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.021224         0.995669   48.2  127085.4   95.8  457.2  \
# 1       2.0  0.021148         0.995683   24.4  127111.0   70.2  481.0
# 2       2.0  0.020908         0.995777   23.2  127124.2   57.0  482.2
# 3       2.0  0.020814         0.995697   40.2  127097.0   84.2  465.2
# 4       2.0  0.020546         0.995504   59.8  127052.8  128.4  445.6
# 5       2.0  0.022406         0.995285   59.0  127025.6  155.6  446.4
# 6       2.0  0.021433         0.995299   75.0  127011.4  169.8  430.4
# 7       2.0  0.021290         0.995365   44.4  127050.4  130.8  461.0
# 8       2.0  0.019678         0.995865   43.8  127114.8   66.4  461.6
# 9       2.0  0.020546         0.995528   39.8  127075.8  105.4  465.6
# 10      2.0  0.019655         0.995644   66.6  127063.8  117.4  438.8
# 11      2.0  0.020189         0.995353   62.2  127031.0  150.2  443.2
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.2928479687176162

# %% [markdown]
# ### Double Concat

# %%
model = DoubleConcatProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] = 2 * (train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP      FN
# epoch
# 0       2.0  2.654988         0.922634  452.8  544762.6  9560.2  2169.0  \
# 1       2.0  0.441527         0.968148  295.0  550637.2  3685.6  2326.8
# 2       2.0  0.101117         0.990730  314.4  553518.0   804.8  2307.4
# 3       2.0  0.084633         0.994446  321.2  553981.2   341.6  2300.6
# 4       2.0  0.080085         0.994789  341.2  554015.2   307.6  2280.6
# 5       2.0  0.075472         0.994949  349.4  554033.0   289.8  2272.4
# 6       2.0  0.070517         0.994996  364.0  554033.4   289.4  2257.8
# 7       2.0  0.065634         0.994926  372.6  554021.4   301.4  2249.2
# 8       2.0  0.060292         0.994979  378.6  554026.4   296.4  2243.2
# 9       2.0  0.054240         0.995033  383.4  554031.8   291.0  2238.4
# 10      2.0  0.048001         0.995040  396.4  554018.0   304.8  2225.4
# 11      2.0  0.042101         0.995049  407.8  554023.6   299.2  2214.0
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy    TP        TN      FP     FN
# epoch
# 0       2.0  0.719011         0.944932  87.2  120552.6  6628.6  418.2  \
# 1       2.0  0.085550         0.989678  47.2  126319.6   861.6  458.2
# 2       2.0  0.068532         0.994738  56.6  126957.8   223.4  448.8
# 3       2.0  0.065446         0.995176  54.0  127016.4   164.8  451.4
# 4       2.0  0.062460         0.995080  69.2  126989.0   192.2  436.2
# 5       2.0  0.058736         0.995263  67.2  127014.4   166.8  438.2
# 6       2.0  0.054949         0.995030  70.8  126981.0   200.2  434.6
# 7       2.0  0.050918         0.995230  65.0  127012.4   168.8  440.4
# 8       2.0  0.046253         0.995404  60.2  127039.4   141.8  445.2
# 9       2.0  0.042003         0.995271  51.0  127031.6   149.6  454.4
# 10      2.0  0.037915         0.995088  55.4  127003.8   177.4  450.0
# 11      2.0  0.033636         0.994943  63.2  126977.4   203.8  442.2
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.23178686436067836

# %% [markdown]
# ### Double Extra Concat

# %%
model = DoubleExtraConcatProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] = 2 * (train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP      FN
# epoch
# 0       2.0  0.049724         0.992584  490.8  553646.4  676.4  2131.0  \
# 1       2.0  0.030449         0.994863  514.4  553930.2  392.6  2107.4
# 2       2.0  0.026519         0.995160  514.2  553973.6  349.2  2107.6
# 3       2.0  0.024492         0.995445  544.2  554002.4  320.4  2077.6
# 4       2.0  0.023625         0.995359  560.2  553976.0  346.8  2061.6
# 5       2.0  0.022372         0.995573  610.8  553992.4  330.4  2011.0
# 6       2.0  0.021699         0.995585  614.0  553995.4  327.4  2007.8
# 7       2.0  0.021106         0.995669  644.2  553993.0  329.8  1977.6
# 8       2.0  0.020676         0.995689  666.6  553990.4  332.4  1955.2
# 9       2.0  0.020531         0.995680  653.2  553992.8  330.0  1968.6
# 10      2.0  0.019967         0.995719  685.6  553986.8  336.0  1936.2
# 11      2.0  0.019925         0.995685  647.8  553996.4  326.4  1974.0
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP     FN
# epoch
# 0       2.0  0.058271         0.986273  123.4  125809.6  1371.6  382.0  \
# 1       2.0  0.034062         0.993476  133.0  126720.4   460.8  372.4
# 2       2.0  0.029981         0.994324  114.4  126847.4   333.8  391.0
# 3       2.0  0.029100         0.993898  109.4  126797.8   383.4  396.0
# 4       2.0  0.028501         0.994415   85.8  126887.6   293.6  419.6
# 5       2.0  0.027952         0.994212  107.4  126840.0   341.2  398.0
# 6       2.0  0.027256         0.994927   88.2  126950.6   230.6  417.2
# 7       2.0  0.026745         0.994819   98.6  126926.4   254.8  406.8
# 8       2.0  0.027458         0.994866  103.8  126927.2   254.0  401.6
# 9       2.0  0.025766         0.995030  112.6  126939.4   241.8  392.8
# 10      2.0  0.024992         0.995063  121.8  126934.4   246.8  383.6
# 11      2.0  0.025871         0.994737  122.0  126892.6   288.6  383.4
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.2849583879341259

# %% [markdown]
# # Feedzai

# %% [markdown]
# ### Feedzai

# %%
model = FeedzaiProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] =  (2 * train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP      FN
# epoch
# 0       2.0  0.036620         0.990816  749.0  553376.2  946.6  1872.8  \
# 1       2.0  0.022135         0.995683  668.2  554008.6  314.2  1953.6
# 2       2.0  0.021855         0.995852  800.2  554013.0  309.8  1821.6
# 3       2.0  0.021250         0.995860  798.2  554016.6  306.2  1823.6
# 4       2.0  0.021794         0.995701  499.6  554129.8  193.0  2122.2
# 5       2.0  0.023642         0.995316  240.2  554092.0  230.8  2381.6
# 6       2.0  0.021728         0.995728  554.4  554081.2  241.6  2067.4
# 7       2.0  0.021547         0.995728  538.6  554106.6  216.2  2083.2
# 8       2.0  0.021781         0.995638  475.2  554090.2  232.6  2146.6
# 9       2.0  0.023807         0.995649  474.2  554138.6  184.2  2147.6
# 10      2.0  0.022780         0.995566  465.2  554089.6  233.2  2156.6
# 11      2.0  0.022214         0.995630  526.2  554074.0  248.8  2095.6
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP     FN
# epoch
# 0       2.0  0.022955         0.996119   79.8  127111.2    70.0  425.6  \
# 1       2.0  0.024638         0.992277   92.0  126609.2   572.0  413.4
# 2       2.0  0.021032         0.996185   78.4  127121.0    60.2  427.0
# 3       2.0  0.019487         0.996473   69.2  127167.0    14.2  436.2
# 4       2.0  0.020354         0.995294  117.4  126968.4   212.8  388.0
# 5       2.0  0.021579         0.996189   42.0  127158.0    23.2  463.4
# 6       2.0  0.021746         0.996340   45.2  127174.0     7.2  460.2
# 7       2.0  0.020653         0.996209  112.6  127090.0    91.2  392.8
# 8       2.0  0.033362         0.995744   48.4  127094.8    86.4  457.0
# 9       2.0  0.021370         0.995857  110.4  127047.2   134.0  395.0
# 10      2.0  0.024809         0.996164   36.6  127160.2    21.0  468.8
# 11      2.0  0.022871         0.994158  132.6  126808.2   373.0  372.8
# ...

# %%
val_df.groupby('epoch').mean()['loss'].min()
# Out:
# 0.018023458495736062

# %% [markdown]
# ### Feedzai Extra

# %%
model = FeedzaiExtraProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] =  (2 * train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP      FN
# epoch
# 0       2.0  0.038457         0.989962  676.0  553239.8  1083.0  1945.8  \
# 1       2.0  0.021504         0.995705  695.6  553955.0   367.8  1926.2
# 2       2.0  0.021357         0.995735  687.0  554001.4   321.4  1934.8
# 3       2.0  0.021368         0.995619  605.4  553996.6   326.2  2016.4
# 4       2.0  0.020207         0.995774  766.0  553966.6   356.2  1855.8
# 5       2.0  0.019418         0.995927  948.0  553904.2   418.6  1673.8
# 6       2.0  0.021642         0.995599  484.8  554085.2   237.6  2137.0
# 7       2.0  0.021705         0.995642  586.6  554040.2   282.6  2035.2
# 8       2.0  0.020725         0.995688  608.0  554057.4   265.4  2013.8
# 9       2.0  0.020493         0.995645  567.8  554074.8   248.0  2054.0
# 10      2.0  0.020959         0.995696  586.8  554085.6   237.2  2035.0
# 11      2.0  0.023081         0.995342  233.4  554148.2   174.6  2388.4
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.020149         0.996177   90.0  127108.4   72.8  415.4  \
# 1       2.0  0.019175         0.996093  139.6  127048.2  133.0  365.8
# 2       2.0  0.019214         0.996216  112.2  127091.2   90.0  393.2
# 3       2.0  0.020065         0.995138  147.0  126918.8  262.4  358.4
# 4       2.0  0.017459         0.996307  116.8  127098.2   83.0  388.6
# 5       2.0  0.018103         0.995794  171.8  126977.8  203.4  333.6
# 6       2.0  0.024124         0.996023    4.2  127174.6    6.6  501.2
# 7       2.0  0.019315         0.996273   78.6  127132.0   49.2  426.8
# 8       2.0  0.019628         0.996091   69.2  127118.2   63.0  436.2
# 9       2.0  0.019375         0.996037   80.0  127100.6   80.6  425.4
# 10      2.0  0.022362         0.994813  104.8  126919.4  261.8  400.6
# 11      2.0  0.022061         0.995962   44.2  127126.8   54.4  461.2
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.4718252902133618

# %% [markdown]
# ### Feedzai Concat

# %%
model = FeedzaiConcatProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] =  (2 * train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold       loss  binary_accuracy     TP        TN       FP      FN
# epoch
# 0       2.0  13.178838         0.804280  402.4  529403.8  24919.0  2219.4  \
# 1       2.0   1.026818         0.942472  310.2  547167.6   7155.2  2311.6
# 2       2.0   0.125799         0.988796  287.2  553111.4   1211.4  2334.6
# 3       2.0   0.097478         0.992301  304.8  553558.4    764.4  2317.0
# 4       2.0   0.088240         0.993207  289.6  553684.6    638.2  2332.2
# 5       2.0   0.082406         0.993656  291.8  553747.6    575.2  2330.0
# 6       2.0   0.077314         0.993961  320.0  553787.0    535.8  2301.8
# 7       2.0   0.072239         0.994185  325.6  553821.8    501.0  2296.2
# 8       2.0   0.068085         0.994392  359.0  553849.2    473.6  2262.8
# 9       2.0   0.065435         0.994564  387.4  553886.6    436.2  2234.4
# 10      2.0   0.063723         0.994659  420.4  553892.6    430.2  2201.4
# 11      2.0   0.062297         0.994766  480.4  553891.0    431.8  2141.4
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy    TP        TN       FP     FN
# epoch
# 0       2.0  4.107438         0.877285  83.4  111898.2  15283.0  422.0  \
# 1       2.0  0.178318         0.983640  28.2  125565.8   1615.4  477.2
# 2       2.0  0.098083         0.992052  26.4  126644.2    537.0  479.0
# 3       2.0  0.083885         0.993727  27.4  126857.6    323.6  478.0
# 4       2.0  0.076969         0.994485  19.8  126962.2    219.0  485.6
# 5       2.0  0.072627         0.994889  17.2  127016.4    164.8  488.2
# 6       2.0  0.067815         0.995051  27.4  127027.0    154.2  478.0
# 7       2.0  0.063392         0.995137  28.4  127037.0    144.2  477.0
# 8       2.0  0.060793         0.995066  32.8  127023.6    157.6  472.6
# 9       2.0  0.059855         0.994941  58.8  126981.6    199.6  446.6
# 10      2.0  0.058433         0.995042  61.6  126991.8    189.4  443.8
# 11      2.0  0.057576         0.995039  80.4  126972.6    208.6  425.0
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.21297074694522103

# %% [markdown]
# ### Feedzai Extra Concat

# %%
model = FeedzaiExtraConcatProduction()

# %%
train_df = pd.read_csv(f'{path}training_runs/train_{model.name}.csv')
train_df['f1_score'] =  (2 * train_df['precision'] * train_df['recall']) / (train_df['precision'] + train_df['recall'])
train_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP      FN
# epoch
# 0       2.0  1.386911         0.956082  515.0  548900.0  5422.8  2106.8  \
# 1       2.0  0.045365         0.994804  538.0  553849.8   473.0  2083.8
# 2       2.0  0.044287         0.994347  491.6  553817.4   505.4  2130.2
# 3       2.0  0.035398         0.994743  373.6  553891.4   431.4  2248.2
# 4       2.0  0.032034         0.994640  396.4  553868.6   454.2  2225.4
# 5       2.0  0.028466         0.994868  410.8  553889.0   433.8  2211.0
# 6       2.0  0.025695         0.995131  415.2  553927.0   395.8  2206.6
# 7       2.0  0.024410         0.995178  392.6  553933.6   389.2  2229.2
# 8       2.0  0.023590         0.995246  407.4  553934.6   388.2  2214.4
# 9       2.0  0.023076         0.995280  421.6  553942.8   380.0  2200.2
# 10      2.0  0.022824         0.995282  418.4  553941.4   381.4  2203.4
# 11      2.0  0.022620         0.995300  436.0  553936.6   386.2  2185.8
# ...

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP     FN
# epoch
# 0       2.0  0.056093         0.993689  118.6  126762.0   419.2  386.8  \
# 1       2.0  0.071539         0.987008  132.2  125893.6  1287.6  373.2
# 2       2.0  0.042832         0.993850  115.0  126786.4   394.8  390.4
# 3       2.0  0.036907         0.993049  107.8  126691.0   490.2  397.6
# 4       2.0  0.034371         0.993041  110.4  126687.4   493.8  395.0
# 5       2.0  0.029704         0.994014  111.0  126811.2   370.0  394.4
# 6       2.0  0.027186         0.994265  101.4  126852.8   328.4  404.0
# 7       2.0  0.026735         0.994440   99.0  126877.6   303.6  406.4
# 8       2.0  0.024986         0.994769  103.8  126914.8   266.4  401.6
# 9       2.0  0.024339         0.994895  112.4  126922.4   258.8  393.0
# 10      2.0  0.023393         0.995006  107.6  126941.4   239.8  397.8
# 11      2.0  0.022531         0.995173  101.4  126968.8   212.4  404.0
# ...

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.2562713333589828
