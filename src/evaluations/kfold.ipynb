# %%
import sys
sys.path.append('../')

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from keras.layers import Dense, Dropout

import tensorflow as tf
import numpy as np
from tqdm import tqdm
from keras.layers import Dense, Dropout, GRU

import pandas as pd
import tensorflow as tf
import numpy as np

tf.random.set_seed(42)
from machine_learning.models import FeedzaiTrain, FeedzaiProduction, FeedzaiExtraTrain, FeedzaiExtraProduction, FeedzaiConcatTrain, FeedzaiConcatProduction, FeedzaiExtraConcatTrain, FeedzaiExtraConcatProduction, DoubleTrain, DoubleProduction, DoubleExtraTrain, DoubleExtraProduction, DoubleConcatTrain, DoubleConcatProduction, DoubleExtraConcatTrain, DoubleExtraConcatProduction

# %%
path = '../'

# %% [markdown]
# # Final Results

# %%
# FINAL RESULTS
results = {
    FeedzaiProduction: 11,
    FeedzaiExtraProduction: 11,
    FeedzaiConcatProduction: 10,
    FeedzaiExtraConcatProduction: 14,
    DoubleProduction: 19,
    DoubleExtraProduction: 3,
    DoubleConcatProduction: 7,
    DoubleExtraConcatProduction: 17
}

# %% [markdown]
# # Feedzai

# %% [markdown]
# ### Feedzai

# %%
model = FeedzaiProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP     FN
# epoch
# 0       2.0  0.021339         0.995842   74.6  127081.0   100.2  430.8  \
# 1       2.0  0.020155         0.995206  129.2  126945.4   235.8  376.2
# 2       2.0  0.020419         0.995615  133.4  126993.4   187.8  372.0
# 3       2.0  0.021895         0.995955  133.0  127037.0   144.2  372.4
# 4       2.0  0.018449         0.996020  151.6  127026.8   154.4  353.8
# 5       2.0  0.019615         0.995111  169.2  126893.2   288.0  336.2
# 6       2.0  0.017690         0.996647  111.0  127147.4    33.8  394.4
# 7       2.0  0.021549         0.995594   37.8  127086.2    95.0  467.6
# 8       2.0  0.021338         0.994186  187.6  126756.8   424.4  317.8
# 9       2.0  0.021077         0.994858  161.6  126868.8   312.4  343.8
# 10      2.0  0.025579         0.989969  225.0  126181.6   999.6  280.4
# 11      2.0  0.017816         0.995385  215.2  126882.2   299.0  290.2
# 12      2.0  0.028524         0.991186  230.0  126331.6   849.6  275.4
# 13      2.0  0.017764         0.996228   36.0  127169.0    12.2  469.4
# 14      2.0  0.025736         0.993267  134.6  126692.6   488.6  370.8
# 15      2.0  0.026399         0.990163  184.4  126247.0   934.2  321.0
# 16      2.0  0.025970         0.991092  232.6  126317.0   864.2  272.8
# 17      2.0  0.032556         0.985503  188.0  125648.6  1532.6  317.4
# 18      2.0  0.020030         0.995453  230.4  126875.6   305.6  275.0
# 19      2.0  0.025226         0.990939  263.8  126266.6   914.6  241.6
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.159578  0.150855  0.742667  0.386522
# 1       0.298645  0.238876  0.760598  0.309831
# 2       0.327090  0.249825  0.746832  0.382693
# 3       0.291998  0.247068  0.793929  0.444332
# 4       0.328501  0.293351  0.801973  0.495761
# 5       0.295695  0.338109  0.814417  0.450922
# 6       0.441833  0.208666  0.813978  0.469129
# 7       0.312017  0.081882  0.816703  0.152410
# 8       0.397079  0.357655  0.828314  0.331694
# 9       0.439295  0.312437  0.830420  0.357498
# 10      0.272735  0.436348  0.839058  0.269876
# 11      0.391933  0.420713  0.827897  0.473905
# 12      0.328683  0.459543  0.815528  0.421321
# 13      0.661720  0.079440  0.794328  0.162152
# 14      0.295920  0.290639  0.734839  0.406550
# 15      0.133264  0.393324  0.796025  0.307039
# 16      0.268146  0.463466  0.827047  0.390109
# 17      0.440952  0.386089  0.812310  0.314329
# 18      0.348303  0.461576  0.833299  0.491003
# 19      0.278607  0.522437  0.829627  0.391111

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.4957614594275282

# %% [markdown]
# ### Feedzai Extra

# %%
model = FeedzaiExtraProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.023325         0.996054  126.4  127056.2  125.0  379.0  \
# 1       2.0  0.020925         0.996150  140.2  127054.8  126.4  365.2
# 2       2.0  0.022947         0.995823   79.6  127073.6  107.6  425.8
# 3       2.0  0.022689         0.996165   77.6  127119.2   62.0  427.8
# 4       2.0  0.023738         0.995627   66.8  127061.4  119.8  438.6
# 5       2.0  0.022675         0.994802  151.6  126871.4  309.8  353.8
# 6       2.0  0.019836         0.996080  130.8  127055.2  126.0  374.6
# 7       2.0  0.019314         0.995964  166.0  127005.2  176.0  339.4
# 8       2.0  0.020423         0.996147   75.8  127118.8   62.4  429.6
# 9       2.0  0.021129         0.995627  121.0  127007.2  174.0  384.4
# 10      2.0  0.020551         0.995812  141.2  127010.6  170.6  364.2
# 11      2.0  0.018811         0.996443  152.2  127080.2  101.0  353.2
# 12      2.0  0.022914         0.995495  176.8  126934.6  246.6  328.6
# 13      2.0  0.025364         0.994989  109.0  126937.6  243.6  396.4
# 14      2.0  0.025911         0.994096  167.2  126765.6  415.6  338.2
# 15      2.0  0.021526         0.995735  178.0  126964.0  217.2  327.4
# 16      2.0  0.022623         0.995136  182.4  126883.0  298.2  323.0
# 17      2.0  0.021546         0.996108  166.8  127022.8  158.4  338.6
# 18      2.0  0.021503         0.995633  188.8  126940.2  241.0  316.6
# 19      2.0  0.023121         0.995454  186.4  126919.6  261.6  319.0
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.288513  0.233321  0.756991  0.429715
# 1       0.263134  0.256535  0.764426  0.409186
# 2       0.176589  0.146100  0.711422  0.396651
# 3       0.208138  0.139919  0.683728  0.418297
# 4       0.143277  0.122873  0.691502  0.329379
# 5       0.193652  0.284495  0.762310  0.379656
# 6       0.306516  0.246342  0.756975  0.450557
# 7       0.313103  0.318545  0.777151  0.517426
# 8       0.317143  0.143027  0.761174  0.327999
# 9       0.254282  0.228862  0.786431  0.335491
# 10      0.256243  0.263862  0.799756  0.428666
# 11      0.350888  0.288419  0.813408  0.527575
# 12      0.249613  0.339933  0.824546  0.479080
# 13      0.354563  0.229209  0.767948  0.289184
# 14      0.292253  0.323999  0.822252  0.454596
# 15      0.357082  0.345295  0.821942  0.383262
# 16      0.358731  0.358125  0.825931  0.362200
# 17      0.364854  0.327679  0.829034  0.405770
# 18      0.373101  0.362373  0.833176  0.426936
# 19      0.340040  0.359656  0.829359  0.406709

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.5275753093132209

# %% [markdown]
# ### Feedzai Concat

# %%
model = FeedzaiConcatProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy    TP        TN      FP     FN
# epoch
# 0       2.0  1.417598         0.932109  51.4  118947.2  8234.0  454.0  \
# 1       2.0  0.199213         0.980421  35.6  125146.4  2034.8  469.8
# 2       2.0  0.088855         0.991756  36.6  126596.2   585.0  468.8
# 3       2.0  0.073447         0.993716  31.4  126852.2   329.0  474.0
# 4       2.0  0.067803         0.994290  35.0  126922.0   259.2  470.4
# 5       2.0  0.063749         0.994691  29.8  126978.6   202.6  475.6
# 6       2.0  0.061279         0.994838  30.8  126996.4   184.8  474.6
# 7       2.0  0.059525         0.994882  41.6  126991.2   190.0  463.8
# 8       2.0  0.056961         0.994996  46.0  127001.4   179.8  459.4
# 9       2.0  0.055304         0.994957  47.6  126994.8   186.4  457.8
# 10      2.0  0.052352         0.994982  60.0  126985.6   195.6  445.4
# 11      2.0  0.049753         0.994965  56.0  126987.4   193.8  449.4
# 12      2.0  0.046901         0.995068  52.2  127004.4   176.8  453.2
# 13      2.0  0.044086         0.995034  48.8  127003.4   177.8  456.6
# 14      2.0  0.041639         0.995002  49.0  126999.2   182.0  456.4
# 15      2.0  0.038707         0.995123  51.2  127012.4   168.8  454.2
# 16      2.0  0.036284         0.995090  43.4  127016.0   165.2  462.0
# 17      2.0  0.034052         0.995151  45.2  127022.0   159.2  460.2
# 18      2.0  0.032174         0.995360  39.8  127054.2   127.0  465.6
# 19      2.0  0.030719         0.995493  46.2  127064.8   116.4  459.2
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.292824  0.096219  0.707363  0.073282
# 1       0.272417  0.066075  0.712929  0.085179
# 2       0.314907  0.070866  0.717925  0.107072
# 3       0.305709  0.059931  0.725714  0.095921
# 4       0.320661  0.069104  0.747253  0.109591
# 5       0.355490  0.063078  0.763100  0.097479
# 6       0.374687  0.064150  0.767532  0.096780
# 7       0.381213  0.086603  0.773236  0.118493
# 8       0.411378  0.096369  0.775267  0.132672
# 9       0.435289  0.100846  0.773970  0.131973
# 10      0.320106  0.123354  0.776080  0.164952
# 11      0.367596  0.115705  0.776562  0.158364
# 12      0.361725  0.107522  0.776655  0.153838
# 13      0.354151  0.100370  0.775336  0.153187
# 14      0.372084  0.101989  0.778197  0.143996
# 15      0.403769  0.105777  0.778197  0.158314
# 16      0.396903  0.087788  0.773156  0.130892
# 17      0.357993  0.093288  0.776601  0.134106
# 18      0.401171  0.081787  0.774713  0.123055
# 19      0.361377  0.092992  0.777647  0.138746

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.16495231446869874

# %% [markdown]
# ### Feedzai Extra Concat

# %%
model = FeedzaiExtraConcatProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.071200         0.991649  123.6  126496.6  684.6  381.8  \
# 1       2.0  0.049942         0.992448  117.8  126604.4  576.8  387.6
# 2       2.0  0.044275         0.993381  112.2  126729.2  452.0  393.2
# 3       2.0  0.040640         0.993538  103.2  126758.2  423.0  402.2
# 4       2.0  0.036516         0.993910   95.8  126813.0  368.2  409.6
# 5       2.0  0.032569         0.994053   89.0  126838.2  343.0  416.4
# 6       2.0  0.028518         0.994616   78.2  126920.8  260.4  427.2
# 7       2.0  0.028392         0.994195   83.8  126861.4  319.8  421.6
# 8       2.0  0.031209         0.992643   84.6  126662.0  519.2  420.8
# 9       2.0  0.032181         0.991613   89.0  126525.6  655.6  416.4
# 10      2.0  0.031805         0.991653  101.4  126518.4  662.8  404.0
# 11      2.0  0.034204         0.990645  101.6  126389.2  792.0  403.8
# 12      2.0  0.034461         0.990837  105.6  126409.8  771.4  399.8
# 13      2.0  0.029980         0.992452  102.6  126619.4  561.8  402.8
# 14      2.0  0.028348         0.992927  118.8  126664.0  517.2  386.6
# 15      2.0  0.027637         0.993550  113.0  126749.6  431.6  392.4
# 16      2.0  0.027190         0.993717  115.0  126769.0  412.2  390.4
# 17      2.0  0.026756         0.993956  113.0  126801.6  379.6  392.4
# 18      2.0  0.026928         0.993853  109.0  126792.4  388.8  396.4
# 19      2.0  0.027319         0.993849  111.4  126789.6  391.6  394.0
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.187058  0.265944  0.776954  0.158433
# 1       0.235658  0.253159  0.777231  0.171519
# 2       0.261192  0.241502  0.776373  0.174530
# 3       0.264898  0.222072  0.770874  0.169275
# 4       0.224771  0.206947  0.772267  0.169357
# 5       0.242313  0.192960  0.776046  0.165029
# 6       0.265496  0.168124  0.775545  0.168824
# 7       0.261541  0.179367  0.782453  0.175381
# 8       0.225087  0.182054  0.793966  0.163917
# 9       0.293917  0.189728  0.800654  0.175381
# 10      0.269452  0.213894  0.809770  0.185125
# 11      0.287577  0.211099  0.805409  0.180620
# 12      0.249120  0.218633  0.793845  0.179313
# 13      0.282561  0.212598  0.811066  0.193101
# 14      0.302119  0.243429  0.821267  0.230315
# 15      0.287405  0.233019  0.819443  0.212608
# 16      0.285153  0.237984  0.822652  0.214229
# 17      0.316978  0.234177  0.822858  0.221037
# 18      0.307042  0.226358  0.823669  0.211585
# 19      0.313835  0.231660  0.822967  0.215412

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.23031521438031985

# %% [markdown]
# # Double

# %% [markdown]
# ### Double

# %%
model = DoubleProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.021887         0.995367  120.0  126975.0  206.2  385.4  \
# 1       2.0  0.022238         0.995509  103.4  127009.8  171.4  402.0
# 2       2.0  0.022454         0.995415  108.2  126993.0  188.2  397.2
# 3       2.0  0.020675         0.995448   96.4  127009.0  172.2  409.0
# 4       2.0  0.021081         0.995255  120.8  126960.0  221.2  384.6
# 5       2.0  0.021924         0.995489  107.4  127003.2  178.0  398.0
# 6       2.0  0.021055         0.995432  138.8  126964.6  216.6  366.6
# 7       2.0  0.021219         0.995622  138.0  126989.6  191.6  367.4
# 8       2.0  0.020918         0.995691  125.0  127011.4  169.8  380.4
# 9       2.0  0.020652         0.995500  124.8  126987.2  194.0  380.6
# 10      2.0  0.021063         0.994893  159.6  126875.0  306.2  345.8
# 11      2.0  0.022342         0.995222  137.4  126939.2  242.0  368.0
# 12      2.0  0.020781         0.995468  108.2  126999.8  181.4  397.2
# 13      2.0  0.022811         0.994452  159.4  126819.0  362.2  346.0
# 14      2.0  0.020327         0.995728   77.0  127064.2  117.0  428.4
# 15      2.0  0.024852         0.993895  177.4  126729.8  451.4  328.0
# 16      2.0  0.021509         0.995012  154.4  126895.4  285.8  351.0
# 17      2.0  0.020171         0.995329  114.6  126975.6  205.6  390.8
# 18      2.0  0.020610         0.994724  168.6  126844.4  336.8  336.8
# 19      2.0  0.020951         0.994640  174.0  126828.2  353.0  331.4
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.219730  0.233510  0.741419  0.377282
# 1       0.235639  0.195260  0.760572  0.343186
# 2       0.230388  0.200137  0.777547  0.316615
# 3       0.231912  0.182456  0.785814  0.325324
# 4       0.256599  0.226595  0.799614  0.359820
# 5       0.249762  0.202511  0.791146  0.350876
# 6       0.332049  0.266714  0.799739  0.316538
# 7       0.334175  0.268297  0.798331  0.355240
# 8       0.335038  0.241874  0.797649  0.329118
# 9       0.310357  0.242205  0.798520  0.320886
# 10      0.277908  0.312548  0.801216  0.359149
# 11      0.296563  0.269253  0.793605  0.344091
# 12      0.235689  0.214594  0.799590  0.267956
# 13      0.260000  0.316245  0.804583  0.349021
# 14      0.322746  0.150378  0.798566  0.234157
# 15      0.251261  0.357360  0.813677  0.354765
# 16      0.277739  0.306111  0.814451  0.361821
# 17      0.283162  0.227733  0.793424  0.312981
# 18      0.274308  0.338143  0.807613  0.372362
# 19      0.271065  0.353544  0.813023  0.377521

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.3775205440854559

# %% [markdown]
# ### Double Extra

# %%
model = DoubleExtraProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN     FP     FN
# epoch
# 0       2.0  0.022134         0.995545   94.4  127023.4  157.8  411.0  \
# 1       2.0  0.021516         0.995703   72.4  127065.6  115.6  433.0
# 2       2.0  0.019466         0.996250   89.0  127118.8   62.4  416.4
# 3       2.0  0.019368         0.996169  121.6  127075.8  105.4  383.8
# 4       2.0  0.021718         0.995476  115.8  126993.2  188.0  389.6
# 5       2.0  0.021322         0.995634   75.4  127053.8  127.4  430.0
# 6       2.0  0.019767         0.996031   76.2  127103.6   77.6  429.2
# 7       2.0  0.020570         0.996014   88.4  127089.2   92.0  417.0
# 8       2.0  0.020553         0.995705   60.6  127077.6  103.6  444.8
# 9       2.0  0.018744         0.995819  111.2  127041.6  139.6  394.2
# 10      2.0  0.021216         0.995561  100.8  127019.0  162.2  404.6
# 11      2.0  0.021741         0.995708   63.6  127075.0  106.2  441.8
# 12      2.0  0.020986         0.995298   97.4  126988.8  192.4  408.0
# 13      2.0  0.021039         0.995115  132.6  126930.2  251.0  372.8
# 14      2.0  0.022063         0.995138  118.4  126947.4  233.8  387.0
# 15      2.0  0.020351         0.995844  105.6  127050.4  130.8  399.8
# 16      2.0  0.019832         0.995632  142.2  126986.6  194.6  363.2
# 17      2.0  0.019318         0.995810  159.8  126991.8  189.4  345.6
# 18      2.0  0.019814         0.995436  153.6  126950.2  231.0  351.8
# 19      2.0  0.018427         0.996233  103.0  127102.6   78.6  402.4
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.252756  0.180403  0.740336  0.298538
# 1       0.228041  0.144749  0.748232  0.231435
# 2       0.340607  0.168053  0.756825  0.371069
# 3       0.317428  0.227107  0.782322  0.431243
# 4       0.236694  0.223563  0.766238  0.364446
# 5       0.227922  0.151898  0.761023  0.236356
# 6       0.294892  0.152843  0.768614  0.298992
# 7       0.360981  0.173621  0.789994  0.285602
# 8       0.347651  0.125066  0.786055  0.203269
# 9       0.340440  0.215580  0.805618  0.309410
# 10      0.315198  0.198565  0.789908  0.299592
# 11      0.365336  0.124739  0.760883  0.200898
# 12      0.270172  0.194123  0.796101  0.253208
# 13      0.299394  0.264033  0.810364  0.317516
# 14      0.248622  0.233291  0.793520  0.286782
# 15      0.410947  0.205215  0.805041  0.326183
# 16      0.337378  0.285585  0.815339  0.361018
# 17      0.348307  0.312070  0.805281  0.402375
# 18      0.334758  0.302896  0.805626  0.383108
# 19      0.423667  0.198737  0.812909  0.334734

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.4312431724412902

# %% [markdown]
# ### Double Concat

# %%
model = DoubleConcatProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy    TP        TN     FP     FN
# epoch
# 0       2.0  0.071174         0.992321  58.6  126646.8  534.4  446.8  \
# 1       2.0  0.050122         0.993976  55.0  126862.0  319.2  450.4
# 2       2.0  0.035251         0.994217  62.4  126885.4  295.8  443.0
# 3       2.0  0.027766         0.993855  63.6  126837.8  343.4  441.8
# 4       2.0  0.026012         0.993956  77.4  126837.0  344.2  428.0
# 5       2.0  0.021395         0.995568  60.2  127060.4  120.8  445.2
# 6       2.0  0.020397         0.995801  64.8  127085.6   95.6  440.6
# 7       2.0  0.020192         0.995808  77.2  127074.2  107.0  428.2
# 8       2.0  0.020225         0.995677  59.0  127075.6  105.6  446.4
# 9       2.0  0.019450         0.995863  51.8  127106.6   74.6  453.6
# 10      2.0  0.019786         0.995785  56.2  127092.2   89.0  449.2
# 11      2.0  0.019675         0.995832  51.6  127102.8   78.4  453.8
# 12      2.0  0.019782         0.995709  50.0  127088.6   92.6  455.4
# 13      2.0  0.020393         0.995747  52.2  127091.2   90.0  453.2
# 14      2.0  0.020357         0.995652  60.2  127071.2  110.0  445.2
# 15      2.0  0.019906         0.995695  60.6  127076.2  105.0  444.8
# 16      2.0  0.019861         0.995684  53.4  127082.0   99.2  452.0
# 17      2.0  0.020447         0.995493  69.4  127041.6  139.6  436.0
# 18      2.0  0.019975         0.995584  77.4  127045.2  136.0  428.0
# 19      2.0  0.019983         0.995603  58.8  127066.2  115.0  446.6
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.324748  0.122917  0.767214  0.139392
# 1       0.362758  0.112458  0.773295  0.148003
# 2       0.342815  0.127714  0.776136  0.174369
# 3       0.325308  0.130055  0.782548  0.179102
# 4       0.321352  0.160792  0.788732  0.200257
# 5       0.314423  0.126021  0.802192  0.172969
# 6       0.359904  0.131060  0.812618  0.189612
# 7       0.396100  0.155932  0.811065  0.217400
# 8       0.320353  0.117625  0.823984  0.168365
# 9       0.386340  0.103467  0.823491  0.157885
# 10      0.359489  0.111330  0.828540  0.164480
# 11      0.369082  0.101726  0.828767  0.150047
# 12      0.350357  0.098763  0.829391  0.150162
# 13      0.417808  0.102176  0.828285  0.152935
# 14      0.356581  0.118154  0.830019  0.168886
# 15      0.402891  0.118795  0.832633  0.167501
# 16      0.393576  0.104437  0.831980  0.147630
# 17      0.409832  0.135714  0.833771  0.191564
# 18      0.403958  0.152773  0.834520  0.210749
# 19      0.414298  0.115440  0.834647  0.155364

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.21740008375415515

# %% [markdown]
# ### Double Extra Concat

# %%
model = DoubleExtraConcatProduction()

# %%
val_df = pd.read_csv(f'{path}training_runs/validation_{model.name}.csv')
val_df['f1_score'] = 2 * (val_df['precision'] * val_df['recall']) / (val_df['precision'] + val_df['recall'])
val_df.groupby('epoch').mean()
# Out:
#        fold      loss  binary_accuracy     TP        TN      FP     FN
# epoch
# 0       2.0  0.048217         0.988046  143.0  126016.0  1165.2  362.4  \
# 1       2.0  0.063543         0.979801  130.4  124972.8  2208.4  375.0
# 2       2.0  0.043533         0.987099  120.6  125916.6  1264.6  384.8
# 3       2.0  0.033872         0.990757  114.8  126390.4   790.8  390.6
# 4       2.0  0.033136         0.992600  137.8  126603.4   577.8  367.6
# 5       2.0  0.032302         0.993118  122.0  126685.6   495.6  383.4
# 6       2.0  0.032055         0.993599  134.6  126734.8   446.4  370.8
# 7       2.0  0.028697         0.994212  105.2  126842.4   338.8  400.2
# 8       2.0  0.030766         0.993517  120.6  126738.4   442.8  384.8
# 9       2.0  0.029379         0.993740  117.6  126769.8   411.4  387.8
# 10      2.0  0.028199         0.993964  111.8  126804.2   377.0  393.6
# 11      2.0  0.027667         0.993890  115.2  126791.4   389.8  390.2
# 12      2.0  0.028983         0.993376  124.8  126716.2   465.0  380.6
# 13      2.0  0.033632         0.992896  131.2  126648.6   532.6  374.2
# 14      2.0  0.029373         0.993455  124.0  126727.0   454.2  381.4
# 15      2.0  0.029090         0.993480  131.6  126722.6   458.6  373.8
# 16      2.0  0.028690         0.993103   95.0  126711.2   470.0  410.4
# 17      2.0  0.028241         0.993666  128.0  126750.0   431.2  377.4
# 18      2.0  0.029174         0.993365   99.8  126739.8   441.4  405.6
# 19      2.0  0.027270         0.993804   97.6  126798.0   383.2  407.8
#
#        precision    recall       auc  f1_score
# epoch
# 0       0.225585  0.296535  0.784724  0.223671
# 1       0.265504  0.272811  0.793323  0.211904
# 2       0.265614  0.252266  0.792885  0.215945
# 3       0.281202  0.236980  0.798449  0.228941
# 4       0.280397  0.284412  0.814203  0.254004
# 5       0.324695  0.255221  0.815517  0.233815
# 6       0.265813  0.278727  0.821436  0.244612
# 7       0.327760  0.217788  0.815080  0.207068
# 8       0.295988  0.249377  0.824430  0.230855
# 9       0.326644  0.244077  0.819552  0.230809
# 10      0.322163  0.230324  0.822668  0.218962
# 11      0.318964  0.236193  0.831882  0.233229
# 12      0.316577  0.257074  0.832601  0.241102
# 13      0.230125  0.266246  0.786195  0.213407
# 14      0.353131  0.253371  0.821874  0.238346
# 15      0.359409  0.267043  0.836344  0.233407
# 16      0.452868  0.201070  0.828643  0.183478
# 17      0.375846  0.257837  0.840860  0.249252
# 18      0.394160  0.207831  0.822294  0.194118
# 19      0.399659  0.201606  0.830644  0.199564

# %%
val_df.groupby('epoch').mean()['f1_score'].max()
# Out:
# 0.25400444111144294
