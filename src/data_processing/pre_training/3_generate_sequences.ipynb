# %% [markdown]
# # Dataset Generation

# %% [markdown]
# Import statements & function definitions:

# %%
import sys
sys.path.append('../')
import pandas as pd
import numpy as np

# %%
CUTOFF_LENGTH = 100

def create_sequences(group: pd.DataFrame, criteria, labels):
    # Order the transactions by 'unix_time' 
    group_ids = group.index.values.tolist()

    # Generate sequences using a sliding window
    sequences = []
    for i in range(len(group_ids)-CUTOFF_LENGTH-1):
        seq = [group_ids[j] for j in range(i, i+CUTOFF_LENGTH)]
        if criteria(seq, labels):
            sequences.append(seq)
        
    return np.ndarray(sequences)

def create_card_sequences(group: pd.DataFrame):
    # Order the transactions by 'unix_time' 
    # group_ids = group.index.values.tolist()

    # Generate sequences using a sliding window
    sequences = []
    for i in range(group.shape[0]-CUTOFF_LENGTH-1):
        seq = group.loc[i: i+CUTOFF_LENGTH].to_numpy()

    return np.ndarray(sequences)

# %% [markdown]
# ## 1. Training set

# %% [markdown]
# Load training set:

# %%
df = pd.read_csv('../../data/raw/modified_fraudTrain.csv')
df.drop(['trans_date_trans_time', 'unix_time'],axis=1,inplace=True)

df.head()
# Out:
#    Unnamed: 0  cc_num  merchant  category       amt  gender   lat  long
# 0           0     146       585        12 -0.408741       1  29.0  93.0  \
# 1           1      51       105         2  0.233378       1  62.0  50.0
# 2           2     860       366         7  0.942184      -1  69.0  95.0
# 3           3     696        39         1 -0.157381      -1  37.0  66.0
# 4           4     195       521        11 -0.176470      -1  62.0  79.0
#
#    city_pop  merch_lat  merch_long  is_fraud  age  trans_timedelta
# 0 -0.282429       49.0        25.0         0   30        -0.634966  \
# 1 -0.293527       57.0        79.0         0   40        -0.634966
# 2 -0.280243       63.0        73.0         0   56        -0.634966
# 3 -0.287590        7.0        72.0         0   52        -0.634966
# 4 -0.293693       58.0        93.0         0   32        -0.634966
#
#    trans_month_sin  trans_month_cos  trans_week_sin  trans_week_cos
# 0        -2.500818         1.529069        1.250178        0.671264  \
# 1        -2.500818         1.529069        1.250178        0.671264
# 2        -2.500818         1.529069        1.250178        0.671264
# 3        -2.500818         1.529069        1.250178        0.671264
# 4        -2.500818         1.529069        1.250178        0.671264
#
#    trans_hour_sin  trans_hour_cos
# 0        0.197699        1.433818
# 1        0.197699        1.433818
# 2        0.197699        1.433818
# 3        0.197699        1.433818
# 4        0.197699        1.433818

# %%
counter = 0
output = np.empty((0, CUTOFF_LENGTH))
output_targets = np.empty((0,))
for i, group in df.groupby('cc_num'):
    if group.shape[0] < CUTOFF_LENGTH:
        continue    # groups too small can't create sequences
    
    labels = group['is_fraud'].to_numpy()
    group.drop(['is_fraud'],axis=1,inplace=True)
    group = group.to_numpy()
    
    seqs = np.array([group[i:i+CUTOFF_LENGTH, 0] for i in range(group.shape[0]-CUTOFF_LENGTH-1)])
    targets = np.array([labels[i+CUTOFF_LENGTH] for i in range(group.shape[0]-CUTOFF_LENGTH-1)])
    output = np.append(output, seqs, axis=0)
    output_targets = np.append(output_targets, targets, axis=0)


output.shape
# Out:
# (1204226, 100)

# %%
np.save('../../data/train/seq_ids', output)
np.save('../../data/train/seq_labels', output_targets)

# %% [markdown]
# ---
# # 2. Test set

# %%
df = pd.read_csv('../../data/raw/modified_fraudTest.csv')
df.drop(['trans_date_trans_time', 'unix_time'],axis=1,inplace=True)

df.head()
# Out:
#    Unnamed: 0  cc_num  merchant  category       amt  gender   lat   long
# 0     1296675     288       442         9 -0.421990      -1  63.0   72.0  \
# 1     1296676     157       392         9 -0.252575       1  62.0  100.0
# 2     1296677      95       468        10 -0.180740       1  62.0   67.0
# 3     1296678     460       504        11 -0.062878      -1  37.0   72.0
# 4     1296679     165       649        14 -0.419918      -1  47.0   42.0
#
#    city_pop  merch_lat  merch_long  is_fraud  age  trans_timedelta
# 0  0.812151       69.0        93.0         0   52         1.426876  \
# 1 -0.293019       57.0        82.0         0   30        -0.102960
# 2 -0.179602       57.0        62.0         0   49        -0.297127
# 3 -0.112365       58.0        67.0         0   32         0.987213
# 4 -0.290286       41.0        32.0         0   65        -0.406467
#
#    trans_month_sin  trans_month_cos  trans_week_sin  trans_week_cos
# 0         0.859281         0.428411       -1.032251        0.671264  \
# 1         0.859281         0.428411       -1.032251        0.671264
# 2         0.859281         0.428411       -1.032251        0.671264
# 3         0.859281         0.428411       -1.032251        0.671264
# 4         0.859281         0.428411       -1.032251        0.671264
#
#    trans_hour_sin  trans_hour_cos
# 0        0.197699       -1.392575
# 1        0.197699       -1.392575
# 2        0.197699       -1.392575
# 3        0.197699       -1.392575
# 4        0.197699       -1.392575

# %%
counter = 0
output = np.empty((0, CUTOFF_LENGTH))
output_targets = np.empty((0,))
for i, group in df.groupby('cc_num'):
    if group.shape[0] < CUTOFF_LENGTH:
        continue    # groups too small can't create sequences
    
    labels = group['is_fraud'].to_numpy()
    group.drop(['is_fraud'],axis=1,inplace=True)
    group = group.to_numpy()
    
    seqs = np.array([group[i:i+CUTOFF_LENGTH, 0] for i in range(group.shape[0]-CUTOFF_LENGTH-1)])
    targets = np.array([labels[i+CUTOFF_LENGTH] for i in range(group.shape[0]-CUTOFF_LENGTH-1)])
    output = np.append(output, seqs, axis=0)
    output_targets = np.append(output_targets, targets, axis=0)


output.shape
# Out:
# (463848, 100)

# %%
np.save('../../data/test/seq_ids', output)
np.save('../../data/test/seq_labels', output_targets)

# %% [markdown]
# ---
#
# ### 1.1. Creating sequences
# A sequence consists of ALL transactions belonging to a single entity, or credit card.
#
# To create sequences, it can be done by simply executing ```pandas.groupby()``` to group transactions by card, which in each group, it is sorted chronologically

# %%
labels = df['is_fraud'].to_numpy()

# %%
groups = df.groupby('cc_num')

fraud = groups.apply(create_sequences, criteria=lambda sequences, labels: labels[sequences[-1]] == 1, labels=labels)
non_fraud = groups.apply(create_sequences, criteria=lambda sequences, labels: labels[sequences[-1]] == 0, labels=labels)
all = groups.apply(create_sequences, criteria=lambda sequences, labels: True, labels=labels)

fraud = [seq for subseqs in fraud for seq in subseqs]
non_fraud = [seq for subseqs in non_fraud for seq in subseqs]
all = [seq for subseqs in all for seq in subseqs]

np.save('../../../data/train/sequences/fraud_train_seq', fraud)
np.save('../../../data/train/sequences/non_fraud_train_seq', non_fraud)

del fraud
del non_fraud
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 groups = df.groupby('cc_num')
#       3 fraud = groups.apply(create_sequences, criteria=lambda sequences, labels: labels[sequences[-1]] == 1, labels=labels)
# ----> 4 non_fraud = groups.apply(create_sequences, criteria=lambda sequences, labels: labels[sequences[-1]] == 0, labels=labels)
#       5 all = groups.apply(create_sequences, criteria=lambda sequences, labels: True, labels=labels)
#       7 fraud = [seq for subseqs in fraud for seq in subseqs]
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1351 with option_context("mode.chained_assignment", None):
#    1352     try:
# -> 1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
#    1363         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/groupby/ops.py:762, in BaseGrouper.apply(self, f, data, axis)
#     759 # This calls DataSplitter.__iter__
#     760 zipped = zip(group_keys, splitter)
# --> 762 for key, group in zipped:
#     763     object.__setattr__(group, "name", key)
#     765     # group might be modified
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1229, in DataSplitter.__iter__(self)
#    1228 def __iter__(self) -> Iterator:
# -> 1229     sdata = self._sorted_data
#    1231     if self.ngroups == 0:
#    1232         # we are inside a generator, rather than raise StopIteration
#    1233         # we merely return signal the end
#    1234         return
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/_libs/properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/groupby/ops.py:1243, in DataSplitter._sorted_data(self)
#    1241 @cache_readonly
#    1242 def _sorted_data(self) -> NDFrameT:
# -> 1243     return self.data.take(self._sort_idx, axis=self.axis)
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/generic.py:3909, in NDFrame.take(self, indices, axis, **kwargs)
#    3833 """
#    3834 Return the elements in the given *positional* indices along an axis.
#    3835
#    (...)
#    3904 3    lion  mammal       80.5
#    3905 """
#    3907 nv.validate_take((), kwargs)
# -> 3909 return self._take(indices, axis)
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/internals/managers.py:963, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
# --> 963 return self.reindex_indexer(
#     964     new_axis=new_labels,
#     965     indexer=indexer,
#     966     axis=axis,
#     967     allow_dups=True,
#     968     copy=None,
#     969 )
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/internals/managers.py:747, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
# --> 747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/internals/managers.py:748, in <listcomp>(.0)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
# --> 748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/internals/blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/array_algos/take.py:133, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     130 else:
#     131     indexer = ensure_platform_int(indexer)
# --> 133 dtype, fill_value, mask_info = _take_preprocess_indexer_and_fill_value(
#     134     arr, indexer, fill_value, allow_fill
#     135 )
#     137 flip_order = False
#     138 if arr.ndim == 2 and arr.flags.f_contiguous:
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/pandas/core/array_algos/take.py:586, in _take_preprocess_indexer_and_fill_value(arr, indexer, fill_value, allow_fill, mask)
#     584 else:
#     585     mask = indexer == -1
# --> 586     needs_masking = bool(mask.any())
#     587 mask_info = mask, needs_masking
#     588 if not needs_masking:
#     589     # if not, then depromote, set fill_value to dummy
#     590     # (it won't be used but we don't want the cython code
#     591     # to crash when trying to cast it to dtype)
#
# File ~/miniconda3/envs/thesis/lib/python3.11/site-packages/numpy/core/_methods.py:54, in _any(a, axis, dtype, out, keepdims, where)
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      51           initial=_NoValue, where=True):
#      52     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 54 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      55     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      56     if where is True:
#      57         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1.2. Transforming transactions to numpy arrays

# %%
df.drop(['trans_date_trans_time', 'unix_time', 'is_fraud'],axis=1,inplace=True)
df.head()
# Out:
#    cc_num  merchant  category       amt  gender   lat  long  city_pop
# 0     146       585        12 -0.408741       1  29.0  93.0 -0.282429  \
# 1      51       105         2  0.233378       1  62.0  50.0 -0.293527
# 2     860       366         7  0.942184      -1  69.0  95.0 -0.280243
# 3     696        39         1 -0.157381      -1  37.0  66.0 -0.287590
# 4     195       521        11 -0.176470      -1  62.0  79.0 -0.293693
#
#    merch_lat  merch_long  age  trans_timedelta  trans_month_sin
# 0       49.0        25.0   30        -0.634966        -2.500818  \
# 1       57.0        79.0   40        -0.634966        -2.500818
# 2       63.0        73.0   56        -0.634966        -2.500818
# 3        7.0        72.0   52        -0.634966        -2.500818
# 4       58.0        93.0   32        -0.634966        -2.500818
#
#    trans_month_cos  trans_week_sin  trans_week_cos  trans_hour_sin
# 0         1.529069        1.250178        0.671264        0.197699  \
# 1         1.529069        1.250178        0.671264        0.197699
# 2         1.529069        1.250178        0.671264        0.197699
# 3         1.529069        1.250178        0.671264        0.197699
# 4         1.529069        1.250178        0.671264        0.197699
#
#    trans_hour_cos
# 0        1.433818
# 1        1.433818
# 2        1.433818
# 3        1.433818
# 4        1.433818

# %%
np.save('../../../data/train/transactions', df.to_numpy())
np.save('../../../data/train/all_transaction_labels', labels)

# %% [markdown]
# # 2. Test set

# %% [markdown]
# For the test set, it will not be necessary since the model will only predict single inputs

# %%
df = pd.read_csv('../../../data/modified/dataframes/modified_fraudTest.csv')
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time  cc_num  merchant  category       amt
# 0     1296675   2020-06-21 12:14:25     288       442         9 -0.421990  \
# 1     1296676   2020-06-21 12:14:33     157       392         9 -0.252575
# 2     1296677   2020-06-21 12:14:53      95       468        10 -0.180740
# 3     1296678   2020-06-21 12:15:15     460       504        11 -0.062878
# 4     1296679   2020-06-21 12:15:17     165       649        14 -0.419918
#
#    gender   lat   long  city_pop  ...  merch_long  is_fraud  age
# 0      -1  63.0   72.0  0.812151  ...        93.0         0   52  \
# 1       1  62.0  100.0 -0.293019  ...        82.0         0   30
# 2       1  62.0   67.0 -0.179602  ...        62.0         0   49
# 3      -1  37.0   72.0 -0.112365  ...        67.0         0   32
# 4      -1  47.0   42.0 -0.290286  ...        32.0         0   65
#
#    trans_timedelta  trans_month_sin  trans_month_cos  trans_week_sin
# 0         1.426876         0.859281         0.428411       -1.032251  \
# 1        -0.102960         0.859281         0.428411       -1.032251
# 2        -0.297127         0.859281         0.428411       -1.032251
# 3         0.987213         0.859281         0.428411       -1.032251
# 4        -0.406467         0.859281         0.428411       -1.032251
#
#    trans_week_cos  trans_hour_sin  trans_hour_cos
# 0        0.671264        0.197699       -1.392575
# 1        0.671264        0.197699       -1.392575
# 2        0.671264        0.197699       -1.392575
# 3        0.671264        0.197699       -1.392575
# 4        0.671264        0.197699       -1.392575
#
# [5 rows x 22 columns]

# %%
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64

# %% [markdown]
# sequences per card

# %%
labels = df['is_fraud'].to_numpy()
groups = df.groupby('cc_num')

# %%
sequences = groups.apply(create_sequences, criteria=lambda sequences, labels: True, labels=labels)

sequences = [seq for subseqs in sequences for seq in subseqs]

sequence_labels = np.apply_along_axis(lambda seq: labels[seq[-1]], 1, sequences)

np.save('../../../data/test/all_test_seq', sequences)
np.save('../../../data/test/all_test_seq_labels', sequence_labels)

del sequences
del sequence_labels

# %%
df.drop(['trans_date_trans_time', 'unix_time', 'is_fraud', 'Unnamed: 0'],axis=1,inplace=True)

np.save('../../../data/test/transactions', df.to_numpy())
np.save('../../../data/test/all_transaction_labels', labels)
